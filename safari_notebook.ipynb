# %% [markdown]
# <a href="https://colab.research.google.com/github/tobiaskatsch/safari/blob/main/safari_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ONLY FOR COLAB: Clone from github

import os
import shutil

repo_name = 'safari'

# Set the SAVE_PATH environment variable to the desired location on Google Drive
os.environ['SAVE_PATH'] = os.path.join("drive", "MyDrive", "ML", repo_name)

# Store your personal access token in a variable
token = "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"

# Replace the 'https://' part in the repository URL with the token and x-oauth-basic for authentication
repo_url = 'https://github.com/tobiaskatsch/safari.git'.replace('https://', f'https://{token}:x-oauth-basic@')


# Clone the repository using the modified URL with the authentication token
# !git clone $repo_url

# Extract all projects to the current direcotry (to keep 'content' the base folder)
for file_or_folder_name in os.listdir(repo_name):
    # Delte existing files previously extracted
    try:
        shutil.rmtree(os.path.join(os.getcwd(), file_or_folder_name))
        os.remove(os.path.join(os.getcwd(), file_or_folder_name))
    except:
        pass
    shutil.move(os.path.join(repo_name, file_or_folder_name), os.path.join(os.getcwd(), file_or_folder_name))

# Remove the repo named folder as all content got extracted already 
os.rmdir(repo_name)
# Out:
# Cloning into 'safari'...
# remote: Enumerating objects: 887, done.
# remote: Counting objects: 100% (887/887), done.
# remote: Compressing objects: 100% (598/598), done.
# remote: Total 887 (delta 302), reused 857 (delta 277), pack-reused 0
# Receiving objects: 100% (887/887), 7.66 MiB | 15.49 MiB/s, done.
# Resolving deltas: 100% (302/302), done.

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m train experiment=synthetics/associative_recall/transformer
# Out:
# CONFIG
# ├── train
# │   └── seed: 0
# │       interval: step
# │       monitor: val/accuracy_ignore_index
# │       mode: max
# │       ema: 0.0
# │       test: false
# │       debug: false
# │       ignore_warnings: false
# │       state:
# │         mode: null
# │         n_context: 0
# │         n_context_eval: 0
# │       ckpt: null
# │       disable_dataset: false
# │       validate_at_start: false
# │       pretrained_model_path: null
# │       pretrained_model_strict_load: true
# │       pretrained_model_state_hook:
# │         _name_: null
# │       post_init_hook:
# │         _name_: null
# │       layer_decay:
# │         _name_: null
# │         decay: 0.7
# │       global_batch_size: 32
# │
# ├── tolerance
# │   └── logdir: ./resume
# │       id: null
# │
# ├── wandb
# │   └── project: long-conv
# │       group: ''
# │       job_type: training
# │       mode: online
# │       name: null
# │       save_dir: .
# │       id: null
# │
# ├── trainer
# ...
